# %% [markdown]
# #Drill #20
# <img src="https://drive.google.com/uc?id=1jFZCf2fOhvOfAPmNW0mMhcCw-vs8Ukfq" width="400">
#
# ####Expected Output:
# <img src="https://drive.google.com/uc?id=193u64JKk7kGDiYO07lZeY4_na5loaQDg" width="250">

# %%
people = 20
cats = 30
dogs = 15

if(people<cats):
  print("too many cats! The world is doomed")

if(people<cats):
  print("Not many cats! The world is saved.")

if(people<dogs):  
   print("The world is drooled on!")

if(people>dogs):  
  print("The world is dry!")

dogs+=5
if(people>=dogs): 
  print("People are greater than equal to dogs.")

if(people<=dogs): 
  print("People are less then equal to dogs.")  

if(people==dogs): 
  print("people are equal to dogs.")
# Out:
# too many cats! The world is doomed
# Not many cats! The world is saved.
# The world is dry!
# People are greater than equal to dogs.
# People are less then equal to dogs.
# people are equal to dogs.

# %% [markdown]
# # Drill #21
# <img src="https://drive.google.com/uc?id=1W7Es2eYu7P2ge50Phx4ufCeQouQz51oZ" width="400">
#
# #### Expected Output
# <img src="https://drive.google.com/uc?id=1VqcfhTIPgR9OvGOEyng65Mpc6OVJhUMs" width="250">

# %%
people = 30
cars = 40
trucks = 15

if(cars > people):
  print("we should take the cars")
elif(cars < people):
  print("we should not take the cars")
else:
  print("we can't decide") 

if(trucks > cars):
  print("There are too many trucks.")
elif(trucks < cars):
  print("Maybe we could take the trucks.")     
else:
  print("We Still can't decide.")

if(people > trucks):
  print("Alright, let's just take the trucks.")   
else:
  print("Fine, let's stay home then.")
# Out:
# we should take the cars
# Maybe we could take the trucks.
# Alright, let's just take the trucks.

# %% [markdown]
# # Drill #22
# <img src="https://drive.google.com/uc?id=1cU17eW9p4Y4653A-Fb2ZnPIdo9kZHRHx" width="400"> <br>
# <img src="https://drive.google.com/uc?id=1nIW0lrApKQORj7L28hnnkFM3rpPHZRkq" width="400">
# #### Expected Output
# <img src="https://drive.google.com/uc?id=1mhrc2muk2WCTqqMIgwbsEfUYEbScLNL4"
# width="250">

# %% [markdown]
# #### 22.1
# Make new parts of game and change what decisions people can make.

# %%
print("""
You enter a dark room with two doors.
do you go through door #1 or door #2
""")

door=input("> ")

if(door=="1"):
  print("There is a gaint bear here, eating a cake.")
  print("What do you do?")
  print("1.Take the cake.")
  print("2.sceam at the bear.")

  bear =input("> ")

  if(bear == "1"):
    print("The Bear eats you face off, good job!")
  elif(bear == "2"):
    print("The Bear eats you legs off, good job!")
  else:
    print(f"Well, doing {bear} is better.")  
    print("Bear runs away")
elif(door == "2"):
    print("You store into the endless abyss at Cthulhu's retiring sopt.\
    you are presented with the following options. What do you choose?")
    print("1. Blueberries")
    print("2. Yellow jackt clothspins")
    print("3. Green jaggery marshmallows")
    insanity = input("> ")
    if(insanity == "1" or insanity == "2"):
      print("Your body survives powered by a mind of jello")
      print("Good job!")
    else:
      print("The insanity rots your eyes into a pool of mud")
      print("Good job!")
# Out:
# You enter a dark room with two doors.
# do you go through door #1 or door #2
#
# > 2
# You store into the endless abyss at Cthulhu's retiring sopt.    you are presented with the following options. What do you choose?
# 1. Blueberries
# 2. Yellow jackt clothspins
# 3. Green jaggery marshmallows
# > 1
# Your body survives powered by a mind of jello
# Good job!
